# %% [markdown]
# <a href="https://colab.research.google.com/github/fmmmgf/machine-learning/blob/main/Session13_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The market research team at AdRight is assigned the task to identify the profile of the typical customer for each treadmill
# product offered by CardioGood Fitness. The market research team decides to investigate whether there are differences across the
# product lines with respect to customer characteristics. The team decides to collect data on individuals who purchased a
# treadmill at a CardioGoodFitness retail store during the prior three months.
# The data are stored in the CardioGoodFitness.csv file.

# %% [markdown]
# Data Dictionary
#
# The team identifies the following customer variables to study:
#   - product purchased, TM195, TM498, or TM798;
#   - gender;
#   - age, in years;
#   - education, in years;
#   - relationship status, single or partnered;
#   - annual household income ;
#   - average number of times the customer plans to use the treadmill each week;
#   - average number of miles the customer expects to walk/run each week;
#   - and self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\sasinha\Downloads\WS\CardioGoodFitness.csv')
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
# information from the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
# five point story (only deals with numerical data)

df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
# mean
df.Age.mean()
# Out:
# 28.788888888888888

# %%
# median
df.Education.median()
# Out:
# 16.0

# %%
# standard deviation
df.Education.std()
# Out:
# 1.6170548978065553

# %%
# variance
df.Education.var()
# Out:
# 2.6148665425201694

# %%
# missing values

df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
# missing value in dataset, we need to fill something in those missing cells as the ML or analysis may not work fine with missing
# values.


# we cannot simply put Zero. we need to impute(replace) those missing values with either mean or median.

# %% [markdown]
# Visualization

# %%
# seaborn
# matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# boxplot

sns.boxplot(x='Age', data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x='Age', y='Gender', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
sns.boxplot(x='MaritalStatus', y='Age', data=df)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='Age'>

# %%
# histogram

# %%
df.hist(figsize = (10,15))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'Usage'}>,
#         <Axes: title={'center': 'Fitness'}>],
#        [<Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Miles'}>]], dtype=object)

# %%
# using seaborn

sns.histplot(df['Age'], kde=True)
# Out:
# C:\Users\sasinha\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# categorical data analysis
# countplot

sns.countplot(x='Gender', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Gender',hue='Product', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# scatter plot (plotting the correlation)

# correlation

# Corr(X,Y) = Cov[X,Y] / ( StdDev(X) ∙ StdDev(Y) )

# %%
# pairplot (it gives the correlation between all variables)

sns.pairplot(df)
# Out:
# C:\Users\sasinha\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sasinha\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sasinha\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# correlation (can be only found for numerical data)

# drop all the categorical variables

df_num = df.drop(['Age'], axis=1)
df_num
# Out:
#     Product  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0     TM195    Male         14        Single      3        4   29562    112
# 1     TM195    Male         15        Single      2        3   31836     75
# 2     TM195  Female         14     Partnered      4        3   30699     66
# 3     TM195    Male         12        Single      3        3   32973     85
# 4     TM195    Male         13     Partnered      4        2   35247     47
# ..      ...     ...        ...           ...    ...      ...     ...    ...
# 175   TM798    Male         21        Single      6        5   83416    200
# 176   TM798    Male         18        Single      5        4   89641    200
# 177   TM798    Male         16        Single      5        5   90886    160
# 178   TM798    Male         18     Partnered      4        5  104581    120
# 179   TM798    Male         18     Partnered      4        5   95508    180
#
# [180 rows x 8 columns]

# %%
df_num = df.drop(['Product','Gender','MaritalStatus'], axis=1)
df_num
# Out:
#      Age  Education  Usage  Fitness  Income  Miles
# 0     18         14      3        4   29562    112
# 1     19         15      2        3   31836     75
# 2     19         14      4        3   30699     66
# 3     19         12      3        3   32973     85
# 4     20         13      4        2   35247     47
# ..   ...        ...    ...      ...     ...    ...
# 175   40         21      6        5   83416    200
# 176   42         18      5        4   89641    200
# 177   45         16      5        5   90886    160
# 178   47         18      4        5  104581    120
# 179   48         18      4        5   95508    180
#
# [180 rows x 6 columns]

# %%
correlation = df_num.corr()
correlation
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
# jointplot (information about outlier with a scatter plot)   ---> bivariate analysis

# %%
sns.jointplot(x='Age', y='Income', data=df)
# Out:
# C:\Users\sasinha\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sasinha\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
